# %%
import os
from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader, DirectoryLoader  #load directories
from langchain_text_splitters import RecursiveCharacterTextSplitter  #text splitter
from youtube_transcript_api import YouTubeTranscriptApi
from langchain_openai import OpenAIEmbeddings  #Embedding model
from langchain_chroma import Chroma  #Vector DB
from dotenv import load_dotenv
import re
# Out:
# C:\Users\ameya\AppData\Local\Temp\ipykernel_65168\2137444568.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader, DirectoryLoader  #load directories

# %%
load_dotenv()
url = "https://www.youtube.com/watch?v=bCz4OMemCcA"

time_map = {}

# %%
def fetch_video_id(url:str):
    video_id = url.split("v=")[-1]
    print(f"--- Video ID: {video_id} ---")
    return video_id

# %%
def sanitize_text(text):
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r' +', ' ', text)
    text = text.strip()
    return text

# %%
def display_chunks(video_id:str):
    ytt = YouTubeTranscriptApi()
    segments = ytt.fetch(video_id)
    for i in range(0, len(segments), 10):
        batch = segments[i:i+10]
        text = " ".join(sanitize_text(seg.text) for seg in batch)
        start = batch[0].start
        minutes = int(start // 60)
        seconds = int(start % 60)
        time_map[minutes*60 + seconds] = text
        print(f"[{minutes*60 + seconds:02d}] {text}\n")

def validation(url:str):
    video_id = fetch_video_id(url)
    docs = display_chunks(video_id)
    return docs

validation(url)
# Out:
# --- Video ID: bCz4OMemCcA ---
# [00] hello guys welcome to my video about the Transformer and this is actually the person 2.0 of my series on the Transformer I had a previous video in which I talked about the Transformer but the audio quality was not good and as suggested by my viewers as the video was really uh had a huge success the viewers suggested me to to improve their audio quality so this this is why I'm doing
#
# [23] this video uh you don't have to watch the previous series because I would be doing basically the same things but with some improvements so I'm actually compensating from some mistakes I made or from some improvements that I could add after watching this video I suggest watch my watching my other video about
#
# ...

# %%
ytt = YouTubeTranscriptApi()
segments = ytt.fetch(video_id = fetch_video_id(url))

def retrieve_btw_timestamps(start:int, end:int):
    return {k:v for k, v in time_map.items() if start <= k <= end}

ground_truth_texts = retrieve_btw_timestamps(0, 90)
text = "\n".join(ground_truth_texts.values())
print(text)
# Out:
# --- Video ID: bCz4OMemCcA ---
# hello guys welcome to my video about the Transformer and this is actually the person 2.0 of my series on the Transformer I had a previous video in which I talked about the Transformer but the audio quality was not good and as suggested by my viewers as the video was really uh had a huge success the viewers suggested me to to improve their audio quality so this this is why I'm doing
# this video uh you don't have to watch the previous series because I would be doing basically the same things but with some improvements so I'm actually compensating from some mistakes I made or from some improvements that I could add after watching this video I suggest watch my watching my other video about
# ...
